# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/MachineLearnia/Python-Machine-Learning/master/Dataset/dataset.csv'
data = pd.read_csv(url, index_col=0, encoding = "ISO-8859-1")
data.head()
# Out:
#                  Patient age quantile SARS-Cov-2 exam result  \
# Patient ID
# 44477f75e8169d2                    13               negative
# 126e9dd13932f68                    17               negative
# a46b4402a0e5696                     8               negative
# f7d619a94f97c45                     5               negative
# d9e41465789c2b5                    15               negative
#
#                  Patient addmited to regular ward (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                               0
# 126e9dd13932f68                                               0
# a46b4402a0e5696                                               0
# f7d619a94f97c45                                               0
# d9e41465789c2b5                                               0
#
#                  Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                                  0
# ...

# %% [markdown]
# # PRE-PROCESSING

# %%
df = data.copy()
df.head()
# Out:
#                  Patient age quantile SARS-Cov-2 exam result  \
# Patient ID
# 44477f75e8169d2                    13               negative
# 126e9dd13932f68                    17               negative
# a46b4402a0e5696                     8               negative
# f7d619a94f97c45                     5               negative
# d9e41465789c2b5                    15               negative
#
#                  Patient addmited to regular ward (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                               0
# 126e9dd13932f68                                               0
# a46b4402a0e5696                                               0
# f7d619a94f97c45                                               0
# d9e41465789c2b5                                               0
#
#                  Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                                  0
# ...

# %% [markdown]
# ## Création des sous-ensembles (suite au EDA)

# %%
missing_rate = df.isna().sum()/df.shape[0]

# %%
blood_columns = list(df.columns[(missing_rate < 0.9) & (missing_rate >0.88)])
viral_columns = list(df.columns[(missing_rate < 0.80) & (missing_rate > 0.75)])

# %%
key_columns = ['Patient age quantile', 'SARS-Cov-2 exam result']

# %%
df = df[key_columns + blood_columns + viral_columns]
df.head()
# Out:
#                  Patient age quantile SARS-Cov-2 exam result  Hematocrit  \
# Patient ID
# 44477f75e8169d2                    13               negative         NaN
# 126e9dd13932f68                    17               negative    0.236515
# a46b4402a0e5696                     8               negative         NaN
# f7d619a94f97c45                     5               negative         NaN
# d9e41465789c2b5                    15               negative         NaN
#
#                  Hemoglobin  Platelets  Mean platelet volume   \
# Patient ID
# 44477f75e8169d2         NaN        NaN                    NaN
# 126e9dd13932f68    -0.02234  -0.517413               0.010677
# a46b4402a0e5696         NaN        NaN                    NaN
# f7d619a94f97c45         NaN        NaN                    NaN
# d9e41465789c2b5         NaN        NaN                    NaN
#
#                  Red blood Cells  Lymphocytes  \
# Patient ID
# 44477f75e8169d2              NaN          NaN
# ...

# %% [markdown]
# ## TrainTest - Nettoyage - Encodage

# %%
from sklearn.model_selection import train_test_split

# %%
trainset, testset = train_test_split(df, test_size=0.2, random_state=0)

# %%
trainset['SARS-Cov-2 exam result'].value_counts()
# Out:
# SARS-Cov-2 exam result
# negative    4068
# positive     447
# Name: count, dtype: int64

# %%
testset['SARS-Cov-2 exam result'].value_counts()
# Out:
# SARS-Cov-2 exam result
# negative    1018
# positive     111
# Name: count, dtype: int64

# %%
def encodage(df):
    code = {'negative':0,
            'positive':1,
            'not_detected':0,
            'detected':1}
    
    for col in df.select_dtypes('object').columns:
        df.loc[:,col] = df[col].map(code)
        
    return df

# %%
def feature_engineering(df):
    df['est malade'] = df[viral_columns].sum(axis=1) >= 1
    df = df.drop(viral_columns, axis=1)
    return df

# %%
def imputation(df):
    #df['is na'] = (df['Parainfluenza 3'].isna()) | (df['Leukocytes'].isna())
    #df = df.fillna(-999)
    df = df.dropna(axis=0)
    return  df

# %%
def preprocessing(df):
    
    df = encodage(df)
    df = feature_engineering(df)
    df = imputation(df)
    
    X = df.drop('SARS-Cov-2 exam result', axis=1)
    y = df['SARS-Cov-2 exam result']
    
    print(y.value_counts())
    
    return X, y

# %%
X_train, y_train = preprocessing(trainset)
# Out:
# SARS-Cov-2 exam result
# 0    422
# 1     65
# Name: count, dtype: int64

# %%
X_test, y_test = preprocessing(testset)
# Out:
# SARS-Cov-2 exam result
# 0    95
# 1    16
# Name: count, dtype: int64

# %% [markdown]
# ## Procédure d'évaluation

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import learning_curve

# %%
def evaluation(model):
    
    model.fit(X_train, y_train)
    ypred = model.predict(X_test)
    
    print(confusion_matrix(y_test, ypred))
    print(classification_report(y_test, ypred))
    
    N, train_score, val_score = learning_curve(model, X_train, y_train,
                                              cv=4, scoring='f1',
                                               train_sizes=np.linspace(0.1, 1, 10))
    
    
    plt.figure(figsize=(12, 8))
    plt.plot(N, train_score.mean(axis=1), label='train score')
    plt.plot(N, val_score.mean(axis=1), label='validation score')
    plt.legend()

# %% [markdown]
# ## Modellisation

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

# %%
preprocessor = make_pipeline(PolynomialFeatures(2, include_bias=False), SelectKBest(f_classif, k=10))

# %%
RandomForest = make_pipeline(preprocessor, RandomForestClassifier(random_state=0))
AdaBoost = make_pipeline(preprocessor, AdaBoostClassifier(random_state=0))
SVM = make_pipeline(preprocessor, StandardScaler(), SVC(random_state=0))
KNN = make_pipeline(preprocessor, StandardScaler(), KNeighborsClassifier())

# %%
dict_of_models = {'RandomForest': RandomForest,
                  'AdaBoost' : AdaBoost,
                  'SVM': SVM,
                  'KNN': KNN
                 }

# %%
for name, model in dict_of_models.items():
    print(name)
    evaluation(model)
# Out:
# RandomForest
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 for name, model in dict_of_models.items():
#       2     print(name)
# ----> 3     evaluation(model)
#
# Cell In[19], line 3, in evaluation(model)
#       1 def evaluation(model):
# ----> 3     model.fit(X_train, y_train)
#       4     ypred = model.predict(X_test)
#       6     print(confusion_matrix(y_test, ypred))
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# ...

# %% [markdown]
# ## OPTIMISATION

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
#RandomizedSearchCV cherche de façon aléatoire différentes combinaisons dans tout le domaine des hyper paramètres que l'on a définit

# %%
SVM
# Out:
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('polynomialfeatures',
#                                   PolynomialFeatures(include_bias=False)),
#                                  ('selectkbest', SelectKBest())])),
#                 ('standardscaler', StandardScaler()),
#                 ('svc', SVC(random_state=0))])

# %%
hyper_params = {'svc__gamma':[1e-3, 1e-4, 0.0005],
                'svc__C':[1, 10, 100, 1000, 3000], 
               'pipeline__polynomialfeatures__degree':[2, 3],
               'pipeline__selectkbest__k': range(45, 60)}

# %%
grid = RandomizedSearchCV(SVM, hyper_params, scoring='recall', cv=4,
                          n_iter=40)
#n_iter=40 veut dire qu'on va faire 40 essais de paramètres pour notre randomizedSearchCV

#scoring='recall' veut dire que c'est le recall qu'on veut optimiser. Ici on veut optimiser le recall
#car on ne veut pas que des gens malades non détectés se baladent dans la nature
grid.fit(X_train, y_train)

#on affiche les hyperparamètres
print(grid.best_params_)

y_pred = grid.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 7
#       1 grid = RandomizedSearchCV(SVM, hyper_params, scoring='recall', cv=4,
#       2                           n_iter=40)
#       3 #n_iter=40 veut dire qu'on va faire 40 essais de paramètres pour notre randomizedSearchCV
#       4
#       5 #scoring='recall' veut dire que c'est le recall qu'on veut optimiser. Ici on veut optimiser le recall
#       6 #car on ne veut pas que des gens malades non détectés se baladent dans la nature
# ----> 7 grid.fit(X_train, y_train)
#       9 #on affiche les hyperparamètres
#      10 print(grid.best_params_)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
# ...

# %%
evaluation(grid.best_estimator_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 evaluation(grid.best_estimator_)
#
# AttributeError: 'RandomizedSearchCV' object has no attribute 'best_estimator_'

# %% [markdown]
# ## Precision Recall Curve

# %%
from sklearn.metrics import precision_recall_curve

# %%
 precision, recall, threshold = precision_recall_curve(y_test, grid.best_estimator_.decision_function(X_test))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 precision, recall, threshold = precision_recall_curve(y_test, grid.best_estimator_.decision_function(X_test))
#
# AttributeError: 'RandomizedSearchCV' object has no attribute 'best_estimator_'

# %%
plt.plot(threshold, precision[:-1], label='precision')
plt.plot(threshold, recall[:-1], label='recall')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 plt.plot(threshold, precision[:-1], label='precision')
#       2 plt.plot(threshold, recall[:-1], label='recall')
#       3 plt.legend()
#
# NameError: name 'threshold' is not defined

# %%
def model_final(model, X, threshold=0):
    return model.decision_function(X) > threshold

# %%
y_pred = model_final(grid.best_estimator_, X_test, threshold=-1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 y_pred = model_final(grid.best_estimator_, X_test, threshold=-1)
#
# AttributeError: 'RandomizedSearchCV' object has no attribute 'best_estimator_'

# %%
from sklearn.metrics import recall_score

# %%
f1_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 f1_score(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
recall_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 recall_score(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined
