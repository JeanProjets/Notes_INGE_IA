# %% [markdown]
# # Introduction à Git

# %% [markdown]
# ### Cloner un repo git avec le nom de dossier par défaut

# %%
git clone https://github.com/JeanProjets/Livres_dev_personnel.git

# %% [markdown]
# ### Cloner un repo git avec un nom de dossier personnalisé

# %%
git clone https://github.com/JeanProjets/Livres_dev_personnel.git Nom_dossier_parent

# %% [markdown]
# ### Pour enlever un fichier du staging area

# %%
git rm --cached NomDuFichier

# %% [markdown]
# ### Historique de tous les commit

# %% [markdown]
# git log

# %% [markdown]
# ### Récupérer ce que l'on avait sur le repo à distance

# %% [markdown]
# git pull

# %% [markdown]
# ### README

# %% [markdown]
# sert de documentation au projet
#     - sommaire
#     - objectifs du code
#     - steps à suivre pour installer le projet en local

# %% [markdown]
# ### Git clone

# %% [markdown]
# Mieux vaut utiliser SSH. C'est beaucoup plus sécurisé. Dans beaucoup d'entreprises, HTTPS est verrouillé.

# %% [markdown]
# ### Supprimer le dernier commit fait en date

# %% [markdown]
# git reset --hard HEAD
#
# git reset --hard HEAD^ (si on veut supprimer le commit précédent)

# %% [markdown]
# ### Git commit best practices

# %% [markdown]
# https://gist.github.com/luismts/495d982e8c5b1a0ced4a57cf3d93cf60

# %% [markdown]
# ### Afficher mes branches

# %% [markdown]
# git branch

# %% [markdown]
# ### Ajouter une branche

# %% [markdown]
# git branch nom_de_la_nouvelle_branche

# %% [markdown]
# ### Changer de branche

# %% [markdown]
# git checkout nom_de_la_branche
#
# #revenir sur la branche précédente:
#
# git checkout -

# %% [markdown]
# ### Créer une nouvelle branche et aller directement dessus

# %% [markdown]
# git checkout -b "nom_de_la_nouvelle_branche"

# %% [markdown]
# ### Supprimer une branche

# %% [markdown]
# git branch -d nom_de_la_branche

# %% [markdown]
# ### Une fois notre nouvelle branche créée en local, on la push en ligne. Pour cela il faut faire :

# %% [markdown]
# #lie notre branche locale à la branche distante correspondante
#
# git push --set-upstream origin nom_de_la_nouvelle_branche
#
# #explication: origin = raccourci vers l’adresse du dépôt en ligne (GitHub, GitLab, etc.). Quand je clone un dépôt Git crée automatiquement un remote appelé origin qui pointe vers cette URL.
# Après avoir fait git push -u origin ma_branche Git mémorise que ma branche locale suit origin/ma_branche . Donc ensuite, un simple git push fonctionne sans préciser origin.
# Est-ce que origin peut s’appeler autrement ? oui ! C’est juste un nom. Tu pourrais avoir : upstream, production, monserveur
#
# Par exemple, dans un projet open-source :
# origin → ton fork
# upstream → le dépôt officiel
# origin = le nom du dépôt distant vers lequel tu envoies ton code.

# %% [markdown]
# ### Mécanisme de merge request

# %% [markdown]
# On écrit notre code sur une branche qui n'est pas la main, on le push sur github, on va dans pull request, on va dans "files changed", on check, puis on va dans l'onget discussion, et on merge la pull request

# %% [markdown]
# Pour travailler avec git en entreprise:
#
# -> se mettre en local sur la Main ou sur la Develop
#
# -> récupérer la dernière version du code (git pull)
#
# -> créer une branche à partir de là
#
# -> sur cette branche, faire vos modifications de code
#
# -> ajouter ces modifications à l'index
#
# -> faire un commit
#
# -> push votre branche locale sur github (1)
#
# -> aller sur github et créer une pull request de votre branche vers la main (ou la develop s'il y en a une)
#
# -> envoyer votre PR à un collègue pour qu'il vérifie le code
#
# -> si votre collègue accepte les modifications, merger la PR
#
# -> enfin, supprimer notre banche localement avec git branch -d nouvelle_feature

# %%
#ordre des commandes

git status
git pull
git checkout -b "update_pipeline_script"
git branch #pour vérifier qu'on est bien sur la bonne branche
git add nom_de_mon_fichier
git commit -m 'description de mes changements'
git push --set-upstream origin nom_de_la_nouvelle_branche

# %% [markdown]
# ### Note

# %% [markdown]
# Si vous en avez marre que git vous dise:
#
# "fatal: The current branch master has no upstream branch.",
#
# vous pouvez soit utiliser:
#
# "git push -u origin head"
#
# (mais il faudra le faire à chaque fois)
#
# soit, avec les dernières version de git, modifier une seule fois votre config :
#
# "git config --global push.autoSetupRemote true"
#
# et ensuite vos "git push" fonctionneront tout le temps, même quand il n'y a pas encore d'upstream branch

# %% [markdown]
# ### Pour rebase

# %%
git rebase main (je ne me rappelle plus si avant ça on doit supprimer nos 
modifs faites localement avec un git reset --hard)
#là normalement je devrais avoir des conflits
git status
#là dans l'exemple il y a script.py flaggé en rouge "both modified"
code script.py (ou vim script.py , il faut juste ouvrir le fichier avec un editeur)
git rebase --continue
git push -f
#là maintenant on peut retourner sur la pull request et on est capable de merge

# %% [markdown]
# ### 🧭 Workflow Git simple (Feature Branch)
#
# #### 1. Partir de main propre
# git checkout main
# git pull origin main
#
# #### 2. Créer une branche feature
# git checkout -b feature/ma-feature
#
# #### 3. Travailler et commit
# git add .
# git commit -m "Message clair"
#
# #### 4. Mettre à jour avant PR
# git fetch origin
# git rebase origin/main
#
# ### En cas de conflit :
# git add .
# git rebase --continue
#
# #### 5. Push
# git push -u origin feature/ma-feature
#
# #### 6. Ouvrir une Pull Request
# → Review
# → Tests
# → Merge (merge commit)
#
# ---
#
# ⚠️ Règles :
# - Jamais de commit direct sur main
# - Rebase uniquement sur sa feature
# - Toujours tester après un rebase

# %% [markdown]
# ---

# %% [markdown]
# # Notes de Paul - Principales commandes git

# %% [markdown]
# ### Rappel de la structure :
#
# Dans git il y a 3 espaces:
#     - le répertoire de travail (les fichiers qu'on modifie).
#     - l'index (les modifications que l'on préparer à mettre dans le git).
#     - et le dépôt .git (la base de données git).

# %% [markdown]
# ## Commandes git

# %% [markdown]
# ### Configuration des outils
#
# git config ... (voir la doc d'embarquement)

# %% [markdown]
# # Travailler avec git
#
# ### Regarder dans quel état est le dépôt
#
# git status
#
# (permet aussi d'avoir les suggestions de git lors des opérations en cours dans le dépôt)
#
# ### Ajouter tous les fichiers à l'index
#
# git add - A
#
# ### Ajouter uniquement les fichiers que l'on connait déjà
#
# git add -u
#
# ### Ajoute [fichier] à l'index
#
# git add [fichier]
#
# ### Enlève [fichier] à l'index
#
# git restore --staged [fichier]
#
# ### Supprimer [fichier] de git
#
# git rm [fichier]
#
# ### Annule les modifications en cours
#
# git restore [fichier]
#
# ### Renomme ou déplace [fichier] dans git
#
# git mv [fichier-ancien-nom] [fichier-nouveau-nom]
#
# ### Crée le commit = enregistre les modifications dans git
#
# git commit -m "message décrivant le commit"

# %% [markdown]
# # Travail en branche
#
# ### Change la copie de travail sur la [branche] spécifiée
#
# git checkout [branche]
#
# ### Liste des branches existantes
#
# git branch -a

# %% [markdown]
# # Consulter l'historique
#
# ### Affiche l'historique de tous les commits
#
# git lg (allias récupéré, ne fonctionne pas out of the box)
#
# ### Affiche les modifications et les métadonnées du [commit]
#
# git show [commit]

# %% [markdown]
# # Synchroniser les changements
#
# ### Récupère tout l'historique depuis github, sans modifier la copie de travail, et nettoie les branches distantes
#
# git fetch --prune
#
# ### Envoie tous les commit sur github
#
# git push
#
# ### Récupère tout l'historique de travail depuis github et met à jour la copie de travail
#
# git pull

# %% [markdown]
# ----

# %% [markdown]
# # Revenir à un état précédent avec Git
#
# ## 1. Voir l’historique des commits
#
# Pour voir les commits existants :
#
# ```bash
# git log --oneline
# ```
#
# Exemple :
#
# ```
# a3f5c21 Fix bug login
# 9c2d1ab Add authentication
# 4e8a912 Initial commit
# ```
#
# Chaque ligne correspond à un **commit identifié par son hash**.
#
# ---
#
# # 2. Revenir temporairement à un ancien commit
#
# Si tu veux simplement **voir ou tester un ancien état du projet** :
#
# ```bash
# git checkout 9c2d1ab
# ```
#
# ⚠️ Tu seras en **detached HEAD** (pas sur une branche).
#
# Pour revenir à ta branche :
#
# ```bash
# git checkout main
# ```
#
# ---
#
# # 3. Revenir en arrière et supprimer les derniers commits
#
# Si ton dernier commit casse le projet :
#
# ```bash
# git reset --hard HEAD~1
# ```
#
# Signification :
#
# * `HEAD~1` → revenir 1 commit en arrière
# * `HEAD~2` → revenir 2 commits en arrière
#
# ⚠️ Cette commande **supprime les modifications définitivement**.
#
# ---
#
# # 4. Revenir à un commit précis
#
# ```bash
# git reset --hard 9c2d1ab
# ```
#
# Le projet reviendra **exactement dans l’état de ce commit**.
#
# ---
#
# # 5. Annuler un commit sans casser l’historique (recommandé en équipe)
#
# Si le code est déjà partagé (GitHub, collaboration) :
#
# ```bash
# git revert 9c2d1ab
# ```
#
# Git crée un **nouveau commit qui annule les modifications du précédent**.
#
# ---
#
# # 6. Annuler des modifications locales non commit
#
# Si tu as modifié des fichiers mais **pas encore fait de commit** :
#
# ```bash
# git restore .
# ```
#
# ou
#
# ```bash
# git checkout -- .
# ```
#
# ---
#
# # 7. Retrouver des commits perdus
#
# Même après un `reset --hard`, Git garde souvent l’historique temporairement :
#
# ```bash
# git reflog
# ```
#
# Tu peux retrouver **des commits supprimés et revenir dessus**.
#
# ---
#
# # Workflow courant quand le code est cassé
#
# ```bash
# git log --oneline
# git reset --hard HEAD~1
# ```
